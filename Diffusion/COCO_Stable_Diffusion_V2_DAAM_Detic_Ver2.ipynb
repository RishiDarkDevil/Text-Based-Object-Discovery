# %% [markdown]
# ### Install Required Packages

# %%
# !pip install daam==0.0.11
# !pip install accelerate  # this is to reduce CPU model load overhead
# !pip install detectron2 -f https://dl.fbaipublicfiles.com/detectron2/wheels/$CUDA_VERSION/torch$TORCH_VERSION/index.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting daam==0.0.11
#   Downloading daam-0.0.11.tar.gz (21 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.8/dist-packages (from daam==0.0.11) (0.18.3)
# Collecting diffusers==0.9.0
#   Downloading diffusers-0.9.0-py3-none-any.whl (453 kB)
#      |████████████████████████████████| 453 kB 24.4 MB/s
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (from daam==0.0.11) (3.4.4)
# Collecting gradio
#   Downloading gradio-3.15.0-py3-none-any.whl (13.8 MB)
#      |████████████████████████████████| 13.8 MB 67.9 MB/s
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.4 MB/s
# Collecting transformers==4.24.0
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 58.2 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from daam==0.0.11) (1.3.5)
# Requirement already satisfied: numba in /usr/local/lib/python3.8/dist-packages (from daam==0.0.11) (0.56.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from daam==0.0.11) (3.7)
# Requirement already satisfied: inflect in /usr/local/lib/python3.8/dist-packages (from daam==0.0.11) (2.1.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from daam==0.0.11) (1.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from diffusers==0.9.0->daam==0.0.11) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from diffusers==0.9.0->daam==0.0.11) (2.23.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (from diffusers==0.9.0->daam==0.0.11) (7.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from diffusers==0.9.0->daam==0.0.11) (2022.6.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from diffusers==0.9.0->daam==0.0.11) (5.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from diffusers==0.9.0->daam==0.0.11) (3.8.2)
# Collecting huggingface-hub>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 79.5 MB/s
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers==4.24.0->daam==0.0.11) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 54.5 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers==4.24.0->daam==0.0.11) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers==4.24.0->daam==0.0.11) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.9.0->daam==0.0.11) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers==4.24.0->daam==0.0.11) (3.0.9)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.8/dist-packages (from ftfy->daam==0.0.11) (0.2.5)
# Collecting pycryptodome
#   Downloading pycryptodome-3.16.0-cp35-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 61.2 MB/s
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.8/dist-packages (from gradio->daam==0.0.11) (2.0.1)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting fastapi
#   Downloading fastapi-0.88.0-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.9 MB/s
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
# Collecting markdown-it-py[linkify,plugins]
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 3.5 MB/s
# Collecting httpx
#   Downloading httpx-0.23.1-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 2.3 MB/s
# Collecting python-multipart
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.8/dist-packages (from gradio->daam==0.0.11) (1.10.2)
# Collecting uvicorn
#   Downloading uvicorn-0.20.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 6.1 MB/s
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from gradio->daam==0.0.11) (3.8.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from gradio->daam==0.0.11) (3.2.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from gradio->daam==0.0.11) (2.11.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.8/dist-packages (from gradio->daam==0.0.11) (2022.11.0)
# Collecting orjson
#   Downloading orjson-3.8.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (278 kB)
#      |████████████████████████████████| 278 kB 60.0 MB/s
# Collecting websockets>=10.0
#   Downloading websockets-10.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      |████████████████████████████████| 106 kB 72.0 MB/s
# Requirement already satisfied: altair>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from gradio->daam==0.0.11) (4.2.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.8/dist-packages (from altair>=4.2.0->gradio->daam==0.0.11) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.8/dist-packages (from altair>=4.2.0->gradio->daam==0.0.11) (4.3.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.8/dist-packages (from altair>=4.2.0->gradio->daam==0.0.11) (0.4)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio->daam==0.0.11) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio->daam==0.0.11) (0.19.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio->daam==0.0.11) (5.10.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=3.0->altair>=4.2.0->gradio->daam==0.0.11) (3.11.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->daam==0.0.11) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->daam==0.0.11) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->daam==0.0.11) (1.15.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio->daam==0.0.11) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio->daam==0.0.11) (6.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio->daam==0.0.11) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio->daam==0.0.11) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio->daam==0.0.11) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio->daam==0.0.11) (1.3.1)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.8/dist-packages (from yarl<2.0,>=1.0->aiohttp->gradio->daam==0.0.11) (2.10)
# Collecting starlette==0.22.0
#   Downloading starlette-0.22.0-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.9 MB/s
# Collecting anyio<5,>=3.4.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 8.2 MB/s
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 9.2 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from httpx->gradio->daam==0.0.11) (2022.12.7)
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 7.5 MB/s
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting mdit-py-plugins
#   Downloading mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 9.7 MB/s
# Collecting linkify-it-py~=1.0
#   Downloading linkify_it_py-1.0.3-py3-none-any.whl (19 kB)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->gradio->daam==0.0.11) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->gradio->daam==0.0.11) (1.4.4)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->daam==0.0.11) (7.1.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba->daam==0.0.11) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba->daam==0.0.11) (57.4.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->diffusers==0.9.0->daam==0.0.11) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->diffusers==0.9.0->daam==0.0.11) (1.24.3)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image->daam==0.0.11) (2.8.8)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from scikit-image->daam==0.0.11) (1.4.1)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from scikit-image->daam==0.0.11) (1.7.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.8/dist-packages (from scikit-image->daam==0.0.11) (2022.10.10)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image->daam==0.0.11) (2.9.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy->daam==0.0.11) (1.0.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy->daam==0.0.11) (0.7.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy->daam==0.0.11) (0.10.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy->daam==0.0.11) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy->daam==0.0.11) (3.0.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy->daam==0.0.11) (6.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy->daam==0.0.11) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy->daam==0.0.11) (2.4.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy->daam==0.0.11) (3.0.10)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy->daam==0.0.11) (3.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy->daam==0.0.11) (8.1.5)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy->daam==0.0.11) (1.0.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy->daam==0.0.11) (2.0.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy->daam==0.0.11) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy->daam==0.0.11) (0.0.3)
# Building wheels for collected packages: daam, ffmpy, python-multipart
#   Building wheel for daam (setup.py) ... done
#   Created wheel for daam: filename=daam-0.0.11-py3-none-any.whl size=23114 sha256=50d4637f0fcf0a5debfc9833d78363c6c517ffda0cf2071599895a1108d00826
#   Stored in directory: /root/.cache/pip/wheels/3f/1c/4a/bc62dcaf14e06e44fc22edff6af4ac26596d6ff47a93e17068
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4711 sha256=63ade4d69d94ee46eca24d311e3749aa2f0c1144ee87af153e5b590a14d62229
#   Stored in directory: /root/.cache/pip/wheels/ff/5b/59/913b443e7369dc04b61f607a746b6f7d83fb65e2e19fcc958d
#   Building wheel for python-multipart (setup.py) ... done
#   Created wheel for python-multipart: filename=python_multipart-0.0.5-py3-none-any.whl size=31678 sha256=e8c7df23b9cb8c7c782b3c6c353869a19f9abd75563d1054875fb6490e319d33
#   Stored in directory: /root/.cache/pip/wheels/9e/fc/1c/cf980e6413d3ee8e70cd8f39e2366b0f487e3e221aeb452eb0
# Successfully built daam ffmpy python-multipart
# Installing collected packages: sniffio, mdurl, uc-micro-py, rfc3986, markdown-it-py, h11, anyio, starlette, mdit-py-plugins, linkify-it-py, httpcore, websockets, uvicorn, tokenizers, python-multipart, pydub, pycryptodome, orjson, huggingface-hub, httpx, ffmpy, fastapi, transformers, gradio, ftfy, diffusers, daam
# Successfully installed anyio-3.6.2 daam-0.0.11 diffusers-0.9.0 fastapi-0.88.0 ffmpy-0.3.0 ftfy-6.1.1 gradio-3.15.0 h11-0.14.0 httpcore-0.16.3 httpx-0.23.1 huggingface-hub-0.11.1 linkify-it-py-1.0.3 markdown-it-py-2.1.0 mdit-py-plugins-0.3.3 mdurl-0.1.2 orjson-3.8.3 pycryptodome-3.16.0 pydub-0.25.1 python-multipart-0.0.5 rfc3986-1.5.0 sniffio-1.3.0 starlette-0.22.0 tokenizers-0.13.2 transformers-4.24.0 uc-micro-py-1.0.1 uvicorn-0.20.0 websockets-10.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting accelerate
#   Downloading accelerate-0.15.0-py3-none-any.whl (191 kB)
#      |████████████████████████████████| 191 kB 15.6 MB/s
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from accelerate) (5.4.8)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from accelerate) (1.21.6)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from accelerate) (6.0)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from accelerate) (1.13.0+cu116)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from accelerate) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->accelerate) (3.0.9)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.4.0->accelerate) (4.4.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.15.0

# %% [markdown]
# We would be running `Stable Diffusion 2` so enable `GPU` under `View Resources > Change runtime type`

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-bf149c61-03c1-6abd-21e3-46f6efb68836)

# %% [markdown]
# ### Load Necessary Libraries

# %% [markdown]
# We will load the necessary libraries required for generating DAAM outputs for input prompts.

# %%
import os
import json
import datetime
from tqdm import tqdm

from matplotlib import pyplot as plt
import numpy as np

from PIL import Image
import cv2

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag 

from diffusers import StableDiffusionPipeline
import daam
import torch

# %% [markdown]
# Download the stopwords for removing stopwords

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ### Load Data

# %% [markdown]
# The below list is a placeholder for any list of prompts, we will be replacing it with a list of prompts from `MS-COCO` text annotations later.

# %%
prompts = [
  "A group of people stand in the back of a truck filled with cotton.",
  "A mother and three children collecting garbage from a blue and white garbage can on the street.",
  "A woman is sitting in a chair reading a book with her head resting on her free hand.",
  "A brown and white dog exiting a yellow and blue ramp in a grassy area.",
  "A boy stands on a rocky mountain."
  ]

# prompts = [
#   "A group of people stand in the back of a truck filled with cotton."
# ]

# %% [markdown]
# Cleaning the prompts. I adopt few ways to clean the prompt:
# - Tokenization
# - Lemmatization
# - Remove stop words
# - Remove non-alphabets
# - Keep only nouns

# %%
# Stopwords
stpwords = set(stopwords.words('english'))

# Lemmatizer
lemmatizer = WordNetLemmatizer() 

def clean_prompt(prompt):
  # tokenize each prompt after they have been converted into lower case
  prompt_tokenized = nltk.word_tokenize(prompt.lower())
  # lemmatize above prompt
  lemmatized_prompt = [lemmatizer.lemmatize(word) for word in prompt_tokenized]
  # pos tag lemmatized prompt above
  pos_tagged_prompt = pos_tag(lemmatized_prompt)
  # keep only the noun words
  fin_prompt = [word for word, pos in pos_tagged_prompt if ('N' in pos and word not in stpwords and word.isalpha())]
  return fin_prompt

# %% [markdown]
# ### Setting up the Pipeline

# %% [markdown]
# #### Brief Overview of the Storage Scheme of the Generated Data

# %% [markdown]
# I will set up the pipeline for generation of the heatmaps and bounding boxes for each generated image for each prompt in the `prompts` list. We will be generating `NUM_IMAGES_PER_PROMPT` images per prompt.
#
# Every output by our code will be stored in `Data-Generated` folder.
#
# I use `COCO` Dataset format to store the bboxes and segmentation for each image.

# %% [markdown]
# #### Set some parameters

# %%
NUM_IMAGES_PER_PROMPT = 2 # Number of images to be generated per prompt
NUM_INFERENCE_STEPS = 50 # Number of inference steps to the Diffusion Model
NAME_OF_DATASET = 'COCO Stable Diffusion 2 Dataset' # Name of the generated dataset
SAVE_AFTER_NUM_IMAGES = 100 # Number of images after which the annotation and caption files will be saved

# %% [markdown]
# Now, let's load the `stabilityai/stable-diffusion-2-base` diffusion model.

# %%
model = StableDiffusionPipeline.from_pretrained('stabilityai/stable-diffusion-2-base')
model = model.to('cuda')
# Out:
# Downloading:   0%|          | 0.00/539 [00:00<?, ?B/s]
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/308 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/738 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/460 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/929 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.46G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.46G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/716 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/335M [00:00<?, ?B/s]

# %% [markdown]
# Setting up the folder structure to generate the data and the dataset information for storing annotations and captions in `COCO` format.

# %%
# The folder that will contain the generated data
os.mkdir('Data-Generated') # Stores everything that is generated
os.mkdir('Data-Generated/images') # Stores generated images
os.mkdir('Data-Generated/annotations') # Stores Annotations
os.mkdir('Data-Generated/captions') # Stores Captions

info = { # Info about the dataset
    "description": NAME_OF_DATASET,
    "url": "https://github.com/RishiDarkDevil/Text-Based-Object-Discovery",
    "version": "1.0",
    "year": 2022,
    "contributor": "Rishi Dey Chowdhury (RishiDarkDevil)",
    "date_created": "2022"
}

licenses = [{ # Licenses associated with the dataset
    'url': 'https://huggingface.co/stabilityai/stable-diffusion-2/blob/main/LICENSE-MODEL',
    'id': 1,
    'name': 'CreativeML Open RAIL++-M License'
}]

images = list() # Stores the generated image info
annotations = list() # Stores the annotation info
categories = list() # Stores the category info
captions = list() # Stores the captions info
cat2id = dict() # Stores the category to id mapping
cat_id = 1 # Assigns id to categories as we go on adding categories which we discover
image_id = 1 # Assigns generated image ids
annotation_id = 1 # Assigns annotations annotation ids
caption_id = 1 # Assigns captions caption ids
save_idx = 1 # The index which stores how many times we saved the json file before

# %% [markdown]
# Let's generate Global Word Attribution HeatMaps.

# %%
class NpEncoder(json.JSONEncoder): # To help encode the unsupported datatypes to json serializable format
  def default(self, obj):
    if isinstance(obj, np.integer):
        return int(obj)
    if isinstance(obj, np.floating):
        return float(obj)
    if isinstance(obj, np.ndarray):
        return obj.tolist()
    return json.JSONEncoder.default(self, obj)

def save(): # Saving annotations and captions when called -- mainly to avoid code repetition
  # Serializing json
  json_obj_det = json.dumps({
      'info': info,
      'licenses': licenses,
      'images': images,
      'annotations': annotations,
      'categories': categories
  }, indent=4, cls=NpEncoder)

  # Writing json
  with open(f"Data-Generated/annotations/object_detect-{save_idx}.json", "w") as outfile:
    outfile.write(json_obj_det)

  print('Saved Annotations')

  # Delete json from python env
  del json_obj_det

  # Serializing json
  json_obj_cap = json.dumps({
      'info': info,
      'licenses': licenses,
      'images': images,
      'annotations': captions,
  }, indent=4, cls=NpEncoder)

  # Writing json
  with open(f"Data-Generated/captions/object_caption-{save_idx}.json", "w") as outfile:
    outfile.write(json_obj_cap)

  # Delete json from python env
  del json_obj_cap

  # Clearing out all the lists except cat2id to maintaining the unique category ids assigned to each new object
  images.clear()
  annotations.clear()
  categories.clear()
  captions.clear()

# %%
try:
  # Iterating overs the prompts
  for i, prompt in enumerate(prompts):

    # Flashing some details
    print(f'Prompt No. {i+1}/{len(prompts)}')
    print('Prompt:', prompt)
    cleaned_prompt = clean_prompt(prompt)
    print('Cleaned Prompt:', ' '.join(cleaned_prompt))
    print('Generating Image...')

    # Updating Categories using cleaned prompt if required and assigning index
    for word in cleaned_prompt:
      if word not in cat2id:
        cat2id[word] = cat_id
        categories.append({"supercategory": word,"id": cat_id,"name": word}) ### FIX SUPERCATEGORY
        cat_id += 1

    for j in range(NUM_IMAGES_PER_PROMPT):

      # Generating images and storing their trace for daam output
      with daam.trace(model) as trc:
        output_image = model(prompt, num_inference_steps=NUM_INFERENCE_STEPS).images[0]
        global_heat_map = trc.compute_global_heat_map()

      # Saving generated Image
      output_image.save(f'Data-Generated/images/{i}_{j}.png')
      print(f'Saving generated Image as.. {i}_{j}.png')

      width, height = output_image.size
      # Image details
      image_det = {
          'license': 1,
          'file_name': f'{i}_{j}.png',
          'height': height,
          'width': width,
          'date_captured': datetime.datetime.now().strftime("%m/%d/%Y, %H:%M:%S"),
          'id': image_id
      }
      images.append(image_det)

      # Captions details
      cap_det = {
          'id': caption_id,
          'image_id': image_id,
          'caption': prompt
      }
      captions.append(cap_det)

      print(f'Generating Annotations for {i}_{j}.png')
      # Generate Global Word Attribution HeatMap
      for word in tqdm(cleaned_prompt):

        # word category id
        word_cat_id = cat2id[word]
        
        # Compute heatmap for a non-stopword
        word_heatmap = global_heat_map.compute_word_heat_map(word).expand_as(output_image).numpy()

        # Casting heatmap from 0-1 floating range to 0-255 unsigned 8 bit integer
        heatmap = np.array(word_heatmap * 255, dtype = np.uint8)

        # Binary threshold of the above heatmap - serves as sort of semantic segmentation for the word
        thresh = cv2.threshold(heatmap, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

        # Find contours from the binary threshold
        cnts = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cnts = cnts[0] if len(cnts) == 2 else cnts[1]

        # Annotating the segmentation and the bounding boxes
        for idx, cnt in enumerate(cnts):
          x,y,w,h = cv2.boundingRect(cnt)
          area = cv2.contourArea(cnt)

          ann_det = { # Annotation details
              'segmentation': [list(cnts[0].squeeze().reshape(1, -1).squeeze())],
              'area': area,
              'iscrowd': 0,
              'image_id': image_id,
              'bbox': [x, y, w, h],
              'category_id': word_cat_id,
              'id': annotation_id,
          }
          annotation_id += 1
          annotations.append(ann_det)
      
      print()
      print('Generated Annotations...')
      
      # Saving Annotations and Captions
      if image_id % SAVE_AFTER_NUM_IMAGES == 0:
        save()
        print(f'Annotations and Captions saved... object_detect-{save_idx}.json and object_caption-{save_idx}.json')

        save_idx += 1

      image_id += 1

      caption_id += 1

  if ((image_id-1) % SAVE_AFTER_NUM_IMAGES != 0 and image_id > 1) or image_id == 1:
    save()

except KeyboardInterrupt: # In case of KeyboardInterrupt save the annotations and captions
  save()

# %% [markdown]
# Let's take a look quickly at the images, annotations, categories and captions json files.

# %%
images
# Out:
# [{'license': 1,
#   'file_name': '0_0.png',
#   'height': 512,
#   'width': 512,
#   'date_captured': datetime.datetime(2022, 12, 23, 12, 13, 23, 605830),
#   'id': 1},
#  {'license': 1,
#   'file_name': '0_1.png',
#   'height': 512,
#   'width': 512,
#   'date_captured': datetime.datetime(2022, 12, 23, 12, 13, 47, 348571),
#   'id': 2},
#  {'license': 1,
#   'file_name': '1_0.png',
#   'height': 512,
#   'width': 512,
#   'date_captured': datetime.datetime(2022, 12, 23, 12, 14, 11, 420311),
#   'id': 3},
#  {'license': 1,
#   'file_name': '1_1.png',
#   'height': 512,
#   'width': 512,
#   'date_captured': datetime.datetime(2022, 12, 23, 12, 14, 35, 787937),
#   'id': 4},
#  {'license': 1,
#   'file_name': '2_0.png',
#   'height': 512,
#   'width': 512,
#   'date_captured': datetime.datetime(2022, 12, 23, 12, 15, 0, 294341),
#   'id': 5},
#  {'license': 1,
#   'file_name': '2_1.png',
#   'height': 512,
#   'width': 512,
#   'date_captured': datetime.datetime(2022, 12, 23, 12, 15, 24, 805035),
#   'id': 6},
#  {'license': 1,
#   'file_name': '3_0.png',
#   'height': 512,
#   'width': 512,
#   'date_captured': datetime.datetime(2022, 12, 23, 12, 15, 49, 312910),
#   'id': 7},
#  {'license': 1,
#   'file_name': '3_1.png',
#   'height': 512,
#   'width': 512,
#   'date_captured': datetime.datetime(2022, 12, 23, 12, 16, 13, 874869),
#   'id': 8},
#  {'license': 1,
#   'file_name': '4_0.png',
#   'height': 512,
#   'width': 512,
#   'date_captured': datetime.datetime(2022, 12, 23, 12, 16, 38, 385217),
#   'id': 9},
#  {'license': 1,
#   'file_name': '4_1.png',
#   'height': 512,
#   'width': 512,
#   'date_captured': datetime.datetime(2022, 12, 23, 12, 17, 2, 913576),
#   'id': 10}]

# %%
annotations
# Out:
# [{'segmentation': [[404, 510, 404, 511]],
#   'area': 0.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [404, 510, 1, 2],
#   'category_id': 1,
#   'id': 1},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 5.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [202, 509, 4, 3],
#   'category_id': 1,
#   'id': 2},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 17.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [144, 507, 6, 5],
#   'category_id': 1,
#   'id': 3},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 37.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [505, 504, 7, 8],
#   'category_id': 1,
#   'id': 4},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 117.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [319, 504, 20, 8],
#   'category_id': 1,
#   'id': 5},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 55.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [164, 503, 10, 9],
#   'category_id': 1,
#   'id': 6},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 76.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [126, 503, 12, 9],
#   'category_id': 1,
#   'id': 7},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 48.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [297, 501, 7, 11],
#   'category_id': 1,
#   'id': 8},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 15.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [272, 494, 5, 7],
#   'category_id': 1,
#   'id': 9},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 259.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [149, 470, 28, 21],
#   'category_id': 1,
#   'id': 10},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 49.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [130, 440, 7, 11],
#   'category_id': 1,
#   'id': 11},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 102.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [173, 438, 15, 10],
#   'category_id': 1,
#   'id': 12},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 3077.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [190, 427, 106, 85],
#   'category_id': 1,
#   'id': 13},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 13.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [274, 417, 6, 4],
#   'category_id': 1,
#   'id': 14},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 23.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [344, 407, 6, 6],
#   'category_id': 1,
#   'id': 15},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 53.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [269, 399, 10, 9],
#   'category_id': 1,
#   'id': 16},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 45.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [32, 395, 9, 9],
#   'category_id': 1,
#   'id': 17},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 42.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [355, 385, 9, 8],
#   'category_id': 1,
#   'id': 18},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 59.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [0, 378, 5, 18],
#   'category_id': 1,
#   'id': 19},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 197.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [67, 374, 22, 13],
#   'category_id': 1,
#   'id': 20},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 878.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [231, 369, 35, 54],
#   'category_id': 1,
#   'id': 21},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 111.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [18, 368, 16, 14],
#   'category_id': 1,
#   'id': 22},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 13.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [13, 361, 6, 4],
#   'category_id': 1,
#   'id': 23},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 9.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [242, 356, 3, 6],
#   'category_id': 1,
#   'id': 24},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 32.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [262, 345, 8, 7],
#   'category_id': 1,
#   'id': 25},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 79.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [359, 342, 11, 11],
#   'category_id': 1,
#   'id': 26},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 70.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [232, 340, 8, 14],
#   'category_id': 1,
#   'id': 27},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 39.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [6, 214, 8, 9],
#   'category_id': 1,
#   'id': 28},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 4.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [58, 194, 5, 3],
#   'category_id': 1,
#   'id': 29},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 5.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [33, 193, 4, 3],
#   'category_id': 1,
#   'id': 30},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 62.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [69, 192, 12, 8],
#   'category_id': 1,
#   'id': 31},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 94.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [0, 184, 15, 10],
#   'category_id': 1,
#   'id': 32},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 1.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [60, 177, 2, 3],
#   'category_id': 1,
#   'id': 33},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 77.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [7, 165, 12, 10],
#   'category_id': 1,
#   'id': 34},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 220.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [36, 159, 28, 11],
#   'category_id': 1,
#   'id': 35},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 11.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [176, 147, 5, 4],
#   'category_id': 1,
#   'id': 36},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 28.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [43, 144, 9, 6],
#   'category_id': 1,
#   'id': 37},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 68.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [15, 142, 10, 11],
#   'category_id': 1,
#   'id': 38},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 43.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [26, 130, 7, 12],
#   'category_id': 1,
#   'id': 39},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 98.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [146, 119, 19, 9],
#   'category_id': 1,
#   'id': 40},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 8.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [499, 116, 5, 4],
#   'category_id': 1,
#   'id': 41},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 249.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [31, 110, 17, 25],
#   'category_id': 1,
#   'id': 42},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 100.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [501, 81, 11, 15],
#   'category_id': 1,
#   'id': 43},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 28.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [371, 74, 9, 6],
#   'category_id': 1,
#   'id': 44},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 14.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [499, 72, 5, 6],
#   'category_id': 1,
#   'id': 45},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 36.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [408, 71, 7, 10],
#   'category_id': 1,
#   'id': 46},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 10.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [330, 58, 4, 5],
#   'category_id': 1,
#   'id': 47},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 21.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [394, 57, 6, 6],
#   'category_id': 1,
#   'id': 48},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 184.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [487, 43, 18, 21],
#   'category_id': 1,
#   'id': 49},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 177.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [438, 38, 22, 12],
#   'category_id': 1,
#   'id': 50},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 12.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [475, 36, 8, 3],
#   'category_id': 1,
#   'id': 51},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 33.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [66, 23, 8, 7],
#   'category_id': 1,
#   'id': 52},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 51.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [469, 17, 12, 7],
#   'category_id': 1,
#   'id': 53},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 133694.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [0, 16, 512, 478],
#   'category_id': 1,
#   'id': 54},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 340.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [411, 0, 48, 18],
#   'category_id': 1,
#   'id': 55},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 2158.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [337, 0, 117, 50],
#   'category_id': 1,
#   'id': 56},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 992.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [263, 0, 66, 40],
#   'category_id': 1,
#   'id': 57},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 65.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [259, 0, 14, 7],
#   'category_id': 1,
#   'id': 58},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 5.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [242, 0, 3, 4],
#   'category_id': 1,
#   'id': 59},
#  {'segmentation': [[404, 510, 404, 511]],
#   'area': 341.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [176, 0, 50, 12],
#   'category_id': 1,
#   'id': 60},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 17.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [507, 506, 5, 6],
#   'category_id': 2,
#   'id': 61},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 43.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [128, 505, 9, 7],
#   'category_id': 2,
#   'id': 62},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 50.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [319, 504, 11, 8],
#   'category_id': 2,
#   'id': 63},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 34.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [298, 503, 7, 9],
#   'category_id': 2,
#   'id': 64},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 3.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [176, 481, 3, 3],
#   'category_id': 2,
#   'id': 65},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 263.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [147, 469, 26, 20],
#   'category_id': 2,
#   'id': 66},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 99.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [276, 456, 12, 12],
#   'category_id': 2,
#   'id': 67},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 70.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [129, 443, 9, 13],
#   'category_id': 2,
#   'id': 68},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 23.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [32, 396, 6, 7],
#   'category_id': 2,
#   'id': 69},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 19.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [49, 393, 8, 5],
#   'category_id': 2,
#   'id': 70},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 367.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [61, 372, 30, 19],
#   'category_id': 2,
#   'id': 71},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 48.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [360, 339, 7, 11],
#   'category_id': 2,
#   'id': 72},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 1050.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [0, 310, 55, 36],
#   'category_id': 2,
#   'id': 73},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 27.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [23, 298, 9, 6],
#   'category_id': 2,
#   'id': 74},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 1.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [482, 221, 2, 3],
#   'category_id': 2,
#   'id': 75},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 28.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [408, 208, 7, 7],
#   'category_id': 2,
#   'id': 76},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 38.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [482, 156, 5, 13],
#   'category_id': 2,
#   'id': 77},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 21.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [176, 147, 7, 5],
#   'category_id': 2,
#   'id': 78},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 9.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [65, 146, 5, 4],
#   'category_id': 2,
#   'id': 79},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 57.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [41, 145, 13, 7],
#   'category_id': 2,
#   'id': 80},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 13.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [90, 132, 5, 5],
#   'category_id': 2,
#   'id': 81},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 30.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [64, 128, 8, 7],
#   'category_id': 2,
#   'id': 82},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 688.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [332, 121, 32, 54],
#   'category_id': 2,
#   'id': 83},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 40.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [149, 120, 15, 5],
#   'category_id': 2,
#   'id': 84},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 12.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [227, 88, 4, 6],
#   'category_id': 2,
#   'id': 85},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 4.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [240, 83, 4, 3],
#   'category_id': 2,
#   'id': 86},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 10.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [290, 73, 4, 5],
#   'category_id': 2,
#   'id': 87},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 48.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [322, 69, 9, 9],
#   'category_id': 2,
#   'id': 88},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 18.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [408, 68, 6, 7],
#   'category_id': 2,
#   'id': 89},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 116795.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [0, 68, 512, 444],
#   'category_id': 2,
#   'id': 90},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 944.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [451, 59, 30, 80],
#   'category_id': 2,
#   'id': 91},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 35.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [246, 55, 7, 8],
#   'category_id': 2,
#   'id': 92},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 8.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [211, 50, 4, 5],
#   'category_id': 2,
#   'id': 93},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 20.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [192, 33, 8, 5],
#   'category_id': 2,
#   'id': 94},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 2.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [219, 30, 2, 3],
#   'category_id': 2,
#   'id': 95},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 79.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [272, 27, 12, 11],
#   'category_id': 2,
#   'id': 96},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 165.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [162, 27, 20, 13],
#   'category_id': 2,
#   'id': 97},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 66.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [393, 26, 8, 17],
#   'category_id': 2,
#   'id': 98},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 33.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [370, 25, 9, 6],
#   'category_id': 2,
#   'id': 99},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 214.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [406, 24, 22, 17],
#   'category_id': 2,
#   'id': 100},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 19.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [68, 23, 6, 6],
#   'category_id': 2,
#   'id': 101},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 106.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [241, 22, 14, 16],
#   'category_id': 2,
#   'id': 102},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 36.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [426, 0, 11, 5],
#   'category_id': 2,
#   'id': 103},
#  {'segmentation': [[510,
#     506,
#     509,
#     507,
#     508,
#     507,
#     507,
#     508,
#     507,
#     511,
#     511,
#     511,
#     511,
#     506]],
#   'area': 6.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [201, 0, 4, 4],
#   'category_id': 2,
#   'id': 104},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 26.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [402, 506, 7, 6],
#   'category_id': 3,
#   'id': 105},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 1.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [170, 457, 2, 2],
#   'category_id': 3,
#   'id': 106},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 1469.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [474, 449, 38, 63],
#   'category_id': 3,
#   'id': 107},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 4.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [131, 448, 3, 4],
#   'category_id': 3,
#   'id': 108},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 103.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [152, 444, 20, 14],
#   'category_id': 3,
#   'id': 109},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 17.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [141, 394, 7, 6],
#   'category_id': 3,
#   'id': 110},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 4.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [150, 392, 5, 4],
#   'category_id': 3,
#   'id': 111},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 18.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [0, 386, 4, 8],
#   'category_id': 3,
#   'id': 112},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 29.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [359, 384, 7, 8],
#   'category_id': 3,
#   'id': 113},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 6.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [162, 381, 3, 5],
#   'category_id': 3,
#   'id': 114},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 9.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [149, 369, 4, 5],
#   'category_id': 3,
#   'id': 115},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 2.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [321, 361, 3, 3],
#   'category_id': 3,
#   'id': 116},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 11.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [265, 345, 4, 6],
#   'category_id': 3,
#   'id': 117},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 24.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [234, 343, 4, 11],
#   'category_id': 3,
#   'id': 118},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 47.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [287, 327, 9, 9],
#   'category_id': 3,
#   'id': 119},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 252.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [302, 326, 33, 22],
#   'category_id': 3,
#   'id': 120},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 210.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [413, 321, 23, 18],
#   'category_id': 3,
#   'id': 121},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 7.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [283, 321, 3, 5],
#   'category_id': 3,
#   'id': 122},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 55.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [255, 321, 10, 8],
#   'category_id': 3,
#   'id': 123},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 20.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [282, 306, 7, 5],
#   'category_id': 3,
#   'id': 124},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 229.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [291, 297, 21, 24],
#   'category_id': 3,
#   'id': 125},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 73.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [252, 296, 11, 13],
#   'category_id': 3,
#   'id': 126},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 5.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [232, 282, 4, 4],
#   'category_id': 3,
#   'id': 127},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 261.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [256, 272, 20, 21],
#   'category_id': 3,
#   'id': 128},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 13.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [289, 193, 4, 7],
#   'category_id': 3,
#   'id': 129},
#  {'segmentation': [[403,
#     506,
#     403,
#     507,
#     402,
#     508,
#     402,
#     511,
#     408,
#     511,
#     408,
#     508,
#     406,
#     506]],
#   'area': 149737.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [0, 0, 512, 400],
#   'category_id': 3,
#   'id': 130},
#  {'segmentation': [[385,
#     310,
#     384,
#     311,
#     381,
#     311,
#     380,
#     312,
#     378,
#     312,
#     377,
#     313,
#     375,
#     313,
#     374,
#     314,
#     373,
#     314,
#     372,
#     315,
#     371,
#     315,
#     370,
#     316,
#     366,
#     316,
#     365,
#     317,
#     364,
#     317,
#     358,
#     323,
#     357,
#     323,
#     356,
#     324,
#     356,
#     325,
#     355,
#     326,
#     355,
#     328,
#     354,
#     329,
#     354,
#     331,
#     353,
#     332,
#     353,
#     343,
#     352,
#     344,
#     352,
#     351,
#     351,
#     352,
#     351,
#     360,
#     352,
#     361,
#     352,
#     366,
#     353,
#     367,
#     353,
#     370,
#     354,
#     371,
#     354,
#     374,
#     355,
#     375,
#     355,
#     379,
#     356,
#     380,
#     356,
#     385,
#     357,
#     386,
#     357,
#     387,
#     360,
#     390,
#     361,
#     390,
#     362,
#     391,
#     364,
#     391,
#     365,
#     390,
#     366,
#     390,
#     369,
#     387,
#     370,
#     387,
#     371,
#     386,
#     372,
#     386,
#     373,
#     385,
#     374,
#     385,
#     375,
#     384,
#     379,
#     384,
#     380,
#     383,
#     381,
#     384,
#     382,
#     384,
#     383,
#     385,
#     384,
#     385,
#     385,
#     386,
#     394,
#     386,
#     400,
#     380,
#     401,
#     380,
#     402,
#     379,
#     402,
#     378,
#     403,
#     377,
#     403,
#     374,
#     404,
#     373,
#     404,
#     372,
#     405,
#     371,
#     405,
#     370,
#     407,
#     368,
#     407,
#     367,
#     408,
#     366,
#     408,
#     365,
#     409,
#     364,
#     409,
#     363,
#     410,
#     362,
#     410,
#     356,
#     411,
#     355,
#     411,
#     332,
#     410,
#     331,
#     410,
#     328,
#     409,
#     327,
#     409,
#     326,
#     408,
#     325,
#     408,
#     324,
#     407,
#     324,
#     404,
#     321,
#     404,
#     320,
#     403,
#     319,
#     403,
#     318,
#     399,
#     314,
#     398,
#     314,
#     397,
#     313,
#     396,
#     313,
#     395,
#     312,
#     394,
#     312,
#     393,
#     311,
#     391,
#     311,
#     390,
#     310]],
#   'area': 3855.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [351, 310, 61, 82],
#   'category_id': 4,
#   'id': 131},
#  {'segmentation': [[385,
#     310,
#     384,
#     311,
#     381,
#     311,
#     380,
#     312,
#     378,
#     312,
#     377,
#     313,
#     375,
#     313,
#     374,
#     314,
#     373,
#     314,
#     372,
#     315,
#     371,
#     315,
#     370,
#     316,
#     366,
#     316,
#     365,
#     317,
#     364,
#     317,
#     358,
#     323,
#     357,
#     323,
#     356,
#     324,
#     356,
#     325,
#     355,
#     326,
#     355,
#     328,
#     354,
#     329,
#     354,
#     331,
#     353,
#     332,
#     353,
#     343,
#     352,
#     344,
#     352,
#     351,
#     351,
#     352,
#     351,
#     360,
#     352,
#     361,
#     352,
#     366,
#     353,
#     367,
#     353,
#     370,
#     354,
#     371,
#     354,
#     374,
#     355,
#     375,
#     355,
#     379,
#     356,
#     380,
#     356,
#     385,
#     357,
#     386,
#     357,
#     387,
#     360,
#     390,
#     361,
#     390,
#     362,
#     391,
#     364,
#     391,
#     365,
#     390,
#     366,
#     390,
#     369,
#     387,
#     370,
#     387,
#     371,
#     386,
#     372,
#     386,
#     373,
#     385,
#     374,
#     385,
#     375,
#     384,
#     379,
#     384,
#     380,
#     383,
#     381,
#     384,
#     382,
#     384,
#     383,
#     385,
#     384,
#     385,
#     385,
#     386,
#     394,
#     386,
#     400,
#     380,
#     401,
#     380,
#     402,
#     379,
#     402,
#     378,
#     403,
#     377,
#     403,
#     374,
#     404,
#     373,
#     404,
#     372,
#     405,
#     371,
#     405,
#     370,
#     407,
#     368,
#     407,
#     367,
#     408,
#     366,
#     408,
#     365,
#     409,
#     364,
#     409,
#     363,
#     410,
#     362,
#     410,
#     356,
#     411,
#     355,
#     411,
#     332,
#     410,
#     331,
#     410,
#     328,
#     409,
#     327,
#     409,
#     326,
#     408,
#     325,
#     408,
#     324,
#     407,
#     324,
#     404,
#     321,
#     404,
#     320,
#     403,
#     319,
#     403,
#     318,
#     399,
#     314,
#     398,
#     314,
#     397,
#     313,
#     396,
#     313,
#     395,
#     312,
#     394,
#     312,
#     393,
#     311,
#     391,
#     311,
#     390,
#     310]],
#   'area': 1864.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [374, 249, 46, 55],
#   'category_id': 4,
#   'id': 132},
#  {'segmentation': [[385,
#     310,
#     384,
#     311,
#     381,
#     311,
#     380,
#     312,
#     378,
#     312,
#     377,
#     313,
#     375,
#     313,
#     374,
#     314,
#     373,
#     314,
#     372,
#     315,
#     371,
#     315,
#     370,
#     316,
#     366,
#     316,
#     365,
#     317,
#     364,
#     317,
#     358,
#     323,
#     357,
#     323,
#     356,
#     324,
#     356,
#     325,
#     355,
#     326,
#     355,
#     328,
#     354,
#     329,
#     354,
#     331,
#     353,
#     332,
#     353,
#     343,
#     352,
#     344,
#     352,
#     351,
#     351,
#     352,
#     351,
#     360,
#     352,
#     361,
#     352,
#     366,
#     353,
#     367,
#     353,
#     370,
#     354,
#     371,
#     354,
#     374,
#     355,
#     375,
#     355,
#     379,
#     356,
#     380,
#     356,
#     385,
#     357,
#     386,
#     357,
#     387,
#     360,
#     390,
#     361,
#     390,
#     362,
#     391,
#     364,
#     391,
#     365,
#     390,
#     366,
#     390,
#     369,
#     387,
#     370,
#     387,
#     371,
#     386,
#     372,
#     386,
#     373,
#     385,
#     374,
#     385,
#     375,
#     384,
#     379,
#     384,
#     380,
#     383,
#     381,
#     384,
#     382,
#     384,
#     383,
#     385,
#     384,
#     385,
#     385,
#     386,
#     394,
#     386,
#     400,
#     380,
#     401,
#     380,
#     402,
#     379,
#     402,
#     378,
#     403,
#     377,
#     403,
#     374,
#     404,
#     373,
#     404,
#     372,
#     405,
#     371,
#     405,
#     370,
#     407,
#     368,
#     407,
#     367,
#     408,
#     366,
#     408,
#     365,
#     409,
#     364,
#     409,
#     363,
#     410,
#     362,
#     410,
#     356,
#     411,
#     355,
#     411,
#     332,
#     410,
#     331,
#     410,
#     328,
#     409,
#     327,
#     409,
#     326,
#     408,
#     325,
#     408,
#     324,
#     407,
#     324,
#     404,
#     321,
#     404,
#     320,
#     403,
#     319,
#     403,
#     318,
#     399,
#     314,
#     398,
#     314,
#     397,
#     313,
#     396,
#     313,
#     395,
#     312,
#     394,
#     312,
#     393,
#     311,
#     391,
#     311,
#     390,
#     310]],
#   'area': 3985.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [471, 236, 41, 127],
#   'category_id': 4,
#   'id': 133},
#  {'segmentation': [[385,
#     310,
#     384,
#     311,
#     381,
#     311,
#     380,
#     312,
#     378,
#     312,
#     377,
#     313,
#     375,
#     313,
#     374,
#     314,
#     373,
#     314,
#     372,
#     315,
#     371,
#     315,
#     370,
#     316,
#     366,
#     316,
#     365,
#     317,
#     364,
#     317,
#     358,
#     323,
#     357,
#     323,
#     356,
#     324,
#     356,
#     325,
#     355,
#     326,
#     355,
#     328,
#     354,
#     329,
#     354,
#     331,
#     353,
#     332,
#     353,
#     343,
#     352,
#     344,
#     352,
#     351,
#     351,
#     352,
#     351,
#     360,
#     352,
#     361,
#     352,
#     366,
#     353,
#     367,
#     353,
#     370,
#     354,
#     371,
#     354,
#     374,
#     355,
#     375,
#     355,
#     379,
#     356,
#     380,
#     356,
#     385,
#     357,
#     386,
#     357,
#     387,
#     360,
#     390,
#     361,
#     390,
#     362,
#     391,
#     364,
#     391,
#     365,
#     390,
#     366,
#     390,
#     369,
#     387,
#     370,
#     387,
#     371,
#     386,
#     372,
#     386,
#     373,
#     385,
#     374,
#     385,
#     375,
#     384,
#     379,
#     384,
#     380,
#     383,
#     381,
#     384,
#     382,
#     384,
#     383,
#     385,
#     384,
#     385,
#     385,
#     386,
#     394,
#     386,
#     400,
#     380,
#     401,
#     380,
#     402,
#     379,
#     402,
#     378,
#     403,
#     377,
#     403,
#     374,
#     404,
#     373,
#     404,
#     372,
#     405,
#     371,
#     405,
#     370,
#     407,
#     368,
#     407,
#     367,
#     408,
#     366,
#     408,
#     365,
#     409,
#     364,
#     409,
#     363,
#     410,
#     362,
#     410,
#     356,
#     411,
#     355,
#     411,
#     332,
#     410,
#     331,
#     410,
#     328,
#     409,
#     327,
#     409,
#     326,
#     408,
#     325,
#     408,
#     324,
#     407,
#     324,
#     404,
#     321,
#     404,
#     320,
#     403,
#     319,
#     403,
#     318,
#     399,
#     314,
#     398,
#     314,
#     397,
#     313,
#     396,
#     313,
#     395,
#     312,
#     394,
#     312,
#     393,
#     311,
#     391,
#     311,
#     390,
#     310]],
#   'area': 369.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [491, 202, 21, 23],
#   'category_id': 4,
#   'id': 134},
#  {'segmentation': [[385,
#     310,
#     384,
#     311,
#     381,
#     311,
#     380,
#     312,
#     378,
#     312,
#     377,
#     313,
#     375,
#     313,
#     374,
#     314,
#     373,
#     314,
#     372,
#     315,
#     371,
#     315,
#     370,
#     316,
#     366,
#     316,
#     365,
#     317,
#     364,
#     317,
#     358,
#     323,
#     357,
#     323,
#     356,
#     324,
#     356,
#     325,
#     355,
#     326,
#     355,
#     328,
#     354,
#     329,
#     354,
#     331,
#     353,
#     332,
#     353,
#     343,
#     352,
#     344,
#     352,
#     351,
#     351,
#     352,
#     351,
#     360,
#     352,
#     361,
#     352,
#     366,
#     353,
#     367,
#     353,
#     370,
#     354,
#     371,
#     354,
#     374,
#     355,
#     375,
#     355,
#     379,
#     356,
#     380,
#     356,
#     385,
#     357,
#     386,
#     357,
#     387,
#     360,
#     390,
#     361,
#     390,
#     362,
#     391,
#     364,
#     391,
#     365,
#     390,
#     366,
#     390,
#     369,
#     387,
#     370,
#     387,
#     371,
#     386,
#     372,
#     386,
#     373,
#     385,
#     374,
#     385,
#     375,
#     384,
#     379,
#     384,
#     380,
#     383,
#     381,
#     384,
#     382,
#     384,
#     383,
#     385,
#     384,
#     385,
#     385,
#     386,
#     394,
#     386,
#     400,
#     380,
#     401,
#     380,
#     402,
#     379,
#     402,
#     378,
#     403,
#     377,
#     403,
#     374,
#     404,
#     373,
#     404,
#     372,
#     405,
#     371,
#     405,
#     370,
#     407,
#     368,
#     407,
#     367,
#     408,
#     366,
#     408,
#     365,
#     409,
#     364,
#     409,
#     363,
#     410,
#     362,
#     410,
#     356,
#     411,
#     355,
#     411,
#     332,
#     410,
#     331,
#     410,
#     328,
#     409,
#     327,
#     409,
#     326,
#     408,
#     325,
#     408,
#     324,
#     407,
#     324,
#     404,
#     321,
#     404,
#     320,
#     403,
#     319,
#     403,
#     318,
#     399,
#     314,
#     398,
#     314,
#     397,
#     313,
#     396,
#     313,
#     395,
#     312,
#     394,
#     312,
#     393,
#     311,
#     391,
#     311,
#     390,
#     310]],
#   'area': 42978.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [0, 87, 185, 316],
#   'category_id': 4,
#   'id': 135},
#  {'segmentation': [[385,
#     310,
#     384,
#     311,
#     381,
#     311,
#     380,
#     312,
#     378,
#     312,
#     377,
#     313,
#     375,
#     313,
#     374,
#     314,
#     373,
#     314,
#     372,
#     315,
#     371,
#     315,
#     370,
#     316,
#     366,
#     316,
#     365,
#     317,
#     364,
#     317,
#     358,
#     323,
#     357,
#     323,
#     356,
#     324,
#     356,
#     325,
#     355,
#     326,
#     355,
#     328,
#     354,
#     329,
#     354,
#     331,
#     353,
#     332,
#     353,
#     343,
#     352,
#     344,
#     352,
#     351,
#     351,
#     352,
#     351,
#     360,
#     352,
#     361,
#     352,
#     366,
#     353,
#     367,
#     353,
#     370,
#     354,
#     371,
#     354,
#     374,
#     355,
#     375,
#     355,
#     379,
#     356,
#     380,
#     356,
#     385,
#     357,
#     386,
#     357,
#     387,
#     360,
#     390,
#     361,
#     390,
#     362,
#     391,
#     364,
#     391,
#     365,
#     390,
#     366,
#     390,
#     369,
#     387,
#     370,
#     387,
#     371,
#     386,
#     372,
#     386,
#     373,
#     385,
#     374,
#     385,
#     375,
#     384,
#     379,
#     384,
#     380,
#     383,
#     381,
#     384,
#     382,
#     384,
#     383,
#     385,
#     384,
#     385,
#     385,
#     386,
#     394,
#     386,
#     400,
#     380,
#     401,
#     380,
#     402,
#     379,
#     402,
#     378,
#     403,
#     377,
#     403,
#     374,
#     404,
#     373,
#     404,
#     372,
#     405,
#     371,
#     405,
#     370,
#     407,
#     368,
#     407,
#     367,
#     408,
#     366,
#     408,
#     365,
#     409,
#     364,
#     409,
#     363,
#     410,
#     362,
#     410,
#     356,
#     411,
#     355,
#     411,
#     332,
#     410,
#     331,
#     410,
#     328,
#     409,
#     327,
#     409,
#     326,
#     408,
#     325,
#     408,
#     324,
#     407,
#     324,
#     404,
#     321,
#     404,
#     320,
#     403,
#     319,
#     403,
#     318,
#     399,
#     314,
#     398,
#     314,
#     397,
#     313,
#     396,
#     313,
#     395,
#     312,
#     394,
#     312,
#     393,
#     311,
#     391,
#     311,
#     390,
#     310]],
#   'area': 30238.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [162, 0, 350, 192],
#   'category_id': 4,
#   'id': 136},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 81.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [503, 499, 9, 13],
#   'category_id': 5,
#   'id': 137},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 2.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [254, 485, 2, 3],
#   'category_id': 5,
#   'id': 138},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 84.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [335, 449, 10, 13],
#   'category_id': 5,
#   'id': 139},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 378.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [142, 446, 27, 32],
#   'category_id': 5,
#   'id': 140},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 130.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [448, 440, 12, 21],
#   'category_id': 5,
#   'id': 141},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 623.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [110, 439, 30, 34],
#   'category_id': 5,
#   'id': 142},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 48.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [422, 436, 9, 11],
#   'category_id': 5,
#   'id': 143},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 32.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [143, 434, 9, 6],
#   'category_id': 5,
#   'id': 144},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 107.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [357, 429, 15, 11],
#   'category_id': 5,
#   'id': 145},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 487.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [444, 395, 21, 39],
#   'category_id': 5,
#   'id': 146},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 296.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [0, 386, 25, 29],
#   'category_id': 5,
#   'id': 147},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 137.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [356, 385, 10, 27],
#   'category_id': 5,
#   'id': 148},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 40.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [506, 374, 6, 10],
#   'category_id': 5,
#   'id': 149},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 72.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [199, 354, 8, 14],
#   'category_id': 5,
#   'id': 150},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 26.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [199, 336, 8, 6],
#   'category_id': 5,
#   'id': 151},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 351.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [355, 330, 21, 35],
#   'category_id': 5,
#   'id': 152},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 1014.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [318, 255, 36, 92],
#   'category_id': 5,
#   'id': 153},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 65.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [0, 151, 13, 8],
#   'category_id': 5,
#   'id': 154},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 24.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [265, 0, 6, 6],
#   'category_id': 5,
#   'id': 155},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 14.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [240, 0, 6, 5],
#   'category_id': 5,
#   'id': 156},
#  {'segmentation': [[508,
#     499,
#     504,
#     503,
#     504,
#     505,
#     503,
#     506,
#     503,
#     511,
#     511,
#     511,
#     511,
#     499]],
#   'area': 133184.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [0, 0, 512, 412],
#   'category_id': 5,
#   'id': 157},
#  {'segmentation': [[500,
#     143,
#     499,
#     144,
#     495,
#     144,
#     494,
#     145,
#     493,
#     145,
#     492,
#     146,
#     491,
#     146,
#     490,
#     147,
#     489,
#     147,
#     488,
#     148,
#     487,
#     148,
#     484,
#     151,
#     484,
#     152,
#     480,
#     156,
#     480,
#     157,
#     478,
#     159,
#     478,
#     161,
#     477,
#     162,
#     477,
#     163,
#     476,
#     164,
#     476,
#     168,
#     475,
#     169,
#     475,
#     178,
#     476,
#     179,
#     476,
#     185,
#     477,
#     186,
#     477,
#     188,
#     478,
#     189,
#     478,
#     190,
#     479,
#     191,
#     479,
#     192,
#     481,
#     194,
#     481,
#     195,
#     485,
#     199,
#     485,
#     200,
#     486,
#     201,
#     487,
#     201,
#     488,
#     202,
#     489,
#     202,
#     490,
#     203,
#     491,
#     203,
#     493,
#     205,
#     494,
#     205,
#     495,
#     206,
#     498,
#     206,
#     499,
#     207,
#     511,
#     207,
#     511,
#     143]],
#   'area': 1918.0,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [475, 143, 37, 65],
#   'category_id': 6,
#   'id': 158},
#  {'segmentation': [[500,
#     143,
#     499,
#     144,
#     495,
#     144,
#     494,
#     145,
#     493,
#     145,
#     492,
#     146,
#     491,
#     146,
#     490,
#     147,
#     489,
#     147,
#     488,
#     148,
#     487,
#     148,
#     484,
#     151,
#     484,
#     152,
#     480,
#     156,
#     480,
#     157,
#     478,
#     159,
#     478,
#     161,
#     477,
#     162,
#     477,
#     163,
#     476,
#     164,
#     476,
#     168,
#     475,
#     169,
#     475,
#     178,
#     476,
#     179,
#     476,
#     185,
#     477,
#     186,
#     477,
#     188,
#     478,
#     189,
#     478,
#     190,
#     479,
#     191,
#     479,
#     192,
#     481,
#     194,
#     481,
#     195,
#     485,
#     199,
#     485,
#     200,
#     486,
#     201,
#     487,
#     201,
#     488,
#     202,
#     489,
#     202,
#     490,
#     203,
#     491,
#     203,
#     493,
#     205,
#     494,
#     205,
#     495,
#     206,
#     498,
#     206,
#     499,
#     207,
#     511,
#     207,
#     511,
#     143]],
#   'area': 24841.5,
#   'iscrowd': 0,
#   'image_id': 1,
#   'bbox': [67, 54, 400, 184],
#   'category_id': 6,
#   'id': 159},
#  {'segmentation': [[58,
#     507,
#     58,
#     508,
#     57,
#     509,
#     57,
#     511,
#     67,
#     511,
#     67,
#     508,
#     66,
#     507]],
#   'area': 38.0,
#   'iscrowd': 0,
#   'image_id': 2,
#   'bbox': [57, 507, 11, 5],
#   'category_id': 1,
#   'id': 160},
#  {'segmentation': [[58,
#     507,
#     58,
#     508,
#     57,
#     509,
#     57,
#     511,
#     67,
#     511,
#     67,
#     508,
#     66,
#     507]],
#   'area': 14.5,
#   'iscrowd': 0,
#   'image_id': 2,
#   'bbox': [361, 506, 4, 6],
#   'category_id': 1,
#   'id': 161},
#  {'segmentation': [[58,
#     507,
#     58,
#     508,
#     57,
#     509,
#     57,
#     511,
#     67,
#     511,
#     67,
#     508,
#     66,
#     507]],
#   'area': 20.5,
#   'iscrowd': 0,
#   'image_id': 2,
#   'bbox': [50, 497, 5, 7],
#   'category_id': 1,
#   'id': 162},
#  {'segmentation': [[58,
#     507,
#     58,
#     508,
#     57,
#     509,
#     57,
#     511,
#     67,
#     511,
#     67,
#     508,
#     66,
#     507]],
#   'area': 7.5,
#   'iscrowd': 0,
#   'image_id': 2,
#   'bbox': [369, 496, 4, 4],
#   'category_id': 1,
#   'id': 163},
#  {'segmentation': [[58,
#     507,
#     58,
#     508,
#     57,
#     509,
#     57,
#     511,
#     67,
#     511,
#     67,
#     508,
#     66,
#     507]],
#   'area': 42.5,
#   'iscrowd': 0,
#   'image_id': 2,
#   'bbox': [59, 481, 7, 11],
#   'category_id': 1,
#   'id': 164},
#  {'segmentation': [[58,
#     507,
#     58,
#     508,
#     57,
#     509,
#     57,
#     511,
#     67,
#     511,
#     67,
#     508,
#     66,
#     507]],
#   'area': 0.5,
#   'iscrowd': 0,
#   'image_id': 2,
#   'bbox': [346, 443, 2, 2],
#   'category_id': 1,
#   'id': 165},
#  {'segmentation': [[58,
#     507,
#     58,
#     508,
#     57,
#     509,
#     57,
#     511,
#     67,
#     511,
#     67,
#     508,
#     66,
#     507]],
#   'area': 35.5,
#   'iscrowd': 0,
#   'image_id': 2,
#   'bbox': [319, 273, 9, 6],
#   'category_id': 1,
#   'id': 166},
#  {'segmentation': [[58,
#     507,
#     58,
#     508,
#     57,
#     509,
#     57,
#     511,
#     67,
#     511,
# ...
#     255,
#     339,
#     255,
#     340,
#     254,
#     341,
#     254,
#     352,
#     255,
#     353,
#     255,
#     354,
#     256,
#     355,
#     256,
#     356,
#     257,
#     357,
#     257,
#     358,
#     258,
#     359,
#     258,
#     360,
#     259,
#     361,
#     259,
#     363,
#     260,
#     364,
#     260,
#     369,
#     259,
#     370,
#     259,
#     371,
#     253,
#     377,
#     253,
#     381,
#     255,
#     383,
#     255,
#     384,
#     256,
#     385,
#     256,
#     388,
#     254,
#     390,
#     253,
#     390,
#     252,
#     391,
#     251,
#     391,
#     250,
#     392,
#     248,
#     392,
#     245,
#     389,
#     243,
#     389,
#     243,
#     391,
#     244,
#     392,
#     244,
#     394,
#     242,
#     396,
#     241,
#     396,
#     240,
#     397,
#     237,
#     397,
#     234,
#     394,
#     234,
#     389,
#     233,
#     388,
#     233,
#     384,
#     232,
#     383,
#     232,
#     382,
#     230,
#     380,
#     229,
#     380,
#     227,
#     378,
#     227,
#     377,
#     229,
#     375,
#     229,
#     372,
#     228,
#     371,
#     225,
#     371,
#     224,
#     372,
#     223,
#     372,
#     223,
#     373,
#     219,
#     377,
#     218,
#     376,
#     213,
#     376,
#     212,
#     377,
#     212,
#     378,
#     209,
#     381,
#     209,
#     385,
#     207,
#     387,
#     206,
#     387,
#     205,
#     388,
#     199,
#     388,
#     198,
#     387,
#     196,
#     387,
#     195,
#     388,
#     195,
#     393,
#     192,
#     396,
#     188,
#     396,
#     183,
#     401,
#     182,
#     401,
#     181,
#     400,
#     179,
#     400,
#     175,
#     396,
#     175,
#     394,
#     174,
#     393,
#     174,
#     388,
#     176,
#     386,
#     177,
#     386,
#     178,
#     385,
#     179,
#     385,
#     181,
#     383,
#     182,
#     383,
#     183,
#     382,
#     186,
#     382,
#     187,
#     381,
#     188,
#     381,
#     189,
#     380,
#     189,
#     379,
#     186,
#     376,
#     184,
#     376,
#     183,
#     375,
#     180,
#     375,
#     179,
#     374,
#     177,
#     374,
#     176,
#     373,
#     173,
#     373,
#     172,
#     372,
#     171,
#     372,
#     170,
#     371,
#     168,
#     371,
#     167,
#     370,
#     166,
#     370,
#     165,
#     369,
#     165,
#     349,
#     166,
#     348,
#     166,
#     346,
#     165,
#     345,
#     165,
#     325,
#     164,
#     324,
#     164,
#     319,
#     163,
#     318,
#     163,
#     316,
#     162,
#     315,
#     162,
#     314,
#     161,
#     313,
#     161,
#     311,
#     160,
#     310,
#     160,
#     309,
#     158,
#     307,
#     158,
#     306,
#     157,
#     305,
#     157,
#     301,
#     156,
#     300,
#     156,
#     299,
#     155,
#     298,
#     155,
#     296,
#     154,
#     295,
#     154,
#     294,
#     153,
#     293,
#     153,
#     292,
#     152,
#     291,
#     152,
#     288,
#     153,
#     287,
#     153,
#     281,
#     152,
#     280,
#     152,
#     277,
#     145,
#     270,
#     144,
#     270,
#     142,
#     268,
#     141,
#     268,
#     138,
#     265,
#     137,
#     265,
#     131,
#     259,
#     131,
#     255,
#     132,
#     254,
#     132,
#     253,
#     133,
#     252,
#     132,
#     251,
#     132,
#     250,
#     131,
#     249,
#     131,
#     248,
#     129,
#     248,
#     127,
#     250,
#     125,
#     250,
#     123,
#     248,
#     122,
#     248,
#     121,
#     247,
#     121,
#     246,
#     120,
#     245,
#     119,
#     245,
#     118,
#     244,
#     117,
#     244,
#     116,
#     243,
#     115,
#     243,
#     114,
#     242,
#     113,
#     242,
#     110,
#     239,
#     110,
#     237,
#     109,
#     236,
#     104,
#     236,
#     102,
#     238,
#     101,
#     238,
#     100,
#     239,
#     99,
#     239,
#     98,
#     240,
#     97,
#     240,
#     96,
#     241,
#     94,
#     241,
#     93,
#     242,
#     90,
#     242,
#     89,
#     243,
#     84,
#     243,
#     83,
#     242,
#     79,
#     242,
#     78,
#     241,
#     75,
#     241,
#     74,
#     240,
#     69,
#     240,
#     68,
#     239,
#     61,
#     239,
#     60,
#     238,
#     58,
#     238,
#     57,
#     237,
#     54,
#     237,
#     53,
#     236,
#     51,
#     236,
#     50,
#     235,
#     46,
#     235,
#     45,
#     234,
#     43,
#     234,
#     42,
#     233,
#     40,
#     233,
#     39,
#     232,
#     38,
#     232,
#     37,
#     231,
#     36,
#     231,
#     34,
#     229,
#     32,
#     229,
#     31,
#     228,
#     30,
#     228,
#     29,
#     227,
#     28,
#     227,
#     27,
#     226,
#     27,
#     224,
#     26,
#     223,
#     26,
#     222,
#     25,
#     221,
#     11,
#     221,
#     10,
#     220,
#     6,
#     220,
#     5,
#     219,
#     0,
#     219,
#     0,
#     511,
#     511,
#     511,
#     511,
#     212,
#     496,
#     212,
#     495,
#     211]],
#   'area': 37.5,
#   'iscrowd': 0,
#   'image_id': 9,
#   'bbox': [106, 37, 9, 7],
#   'category_id': 23,
#   'id': 694},
#  {'segmentation': [[492,
#     211,
#     491,
#     212,
#     487,
#     212,
#     486,
#     213,
#     485,
#     213,
#     484,
#     214,
#     483,
#     214,
#     482,
#     215,
#     481,
#     215,
#     480,
#     216,
#     479,
#     216,
#     478,
#     217,
#     476,
#     217,
#     475,
#     218,
#     472,
#     218,
#     471,
#     219,
#     465,
#     219,
#     464,
#     218,
#     461,
#     218,
#     460,
#     217,
#     446,
#     217,
#     445,
#     216,
#     437,
#     216,
#     436,
#     217,
#     429,
#     217,
#     428,
#     218,
#     421,
#     218,
#     420,
#     219,
#     412,
#     219,
#     411,
#     218,
#     407,
#     218,
#     406,
#     217,
#     397,
#     217,
#     396,
#     218,
#     390,
#     218,
#     389,
#     219,
#     384,
#     219,
#     383,
#     220,
#     380,
#     220,
#     379,
#     221,
#     378,
#     221,
#     377,
#     222,
#     376,
#     222,
#     373,
#     225,
#     372,
#     225,
#     369,
#     228,
#     368,
#     228,
#     367,
#     229,
#     366,
#     229,
#     364,
#     231,
#     364,
#     232,
#     361,
#     235,
#     358,
#     235,
#     357,
#     234,
#     353,
#     234,
#     352,
#     233,
#     350,
#     233,
#     349,
#     232,
#     348,
#     232,
#     347,
#     231,
#     346,
#     231,
#     345,
#     230,
#     344,
#     230,
#     343,
#     229,
#     341,
#     229,
#     340,
#     228,
#     337,
#     228,
#     336,
#     227,
#     331,
#     227,
#     330,
#     226,
#     324,
#     226,
#     323,
#     227,
#     320,
#     227,
#     319,
#     228,
#     318,
#     228,
#     316,
#     230,
#     316,
#     231,
#     312,
#     235,
#     311,
#     235,
#     308,
#     238,
#     308,
#     241,
#     305,
#     244,
#     304,
#     244,
#     303,
#     245,
#     302,
#     245,
#     301,
#     246,
#     300,
#     246,
#     300,
#     247,
#     299,
#     248,
#     299,
#     250,
#     297,
#     252,
#     297,
#     253,
#     294,
#     256,
#     291,
#     256,
#     290,
#     257,
#     286,
#     257,
#     285,
#     258,
#     282,
#     258,
#     281,
#     259,
#     274,
#     259,
#     273,
#     260,
#     269,
#     260,
#     268,
#     261,
#     268,
#     263,
#     267,
#     264,
#     267,
#     265,
#     265,
#     267,
#     264,
#     267,
#     263,
#     268,
#     261,
#     268,
#     260,
#     269,
#     260,
#     270,
#     258,
#     272,
#     258,
#     274,
#     257,
#     275,
#     257,
#     279,
#     258,
#     280,
#     258,
#     283,
#     259,
#     284,
#     259,
#     288,
#     258,
#     289,
#     258,
#     291,
#     259,
#     292,
#     259,
#     301,
#     258,
#     302,
#     258,
#     303,
#     257,
#     304,
#     257,
#     306,
#     256,
#     307,
#     256,
#     311,
#     257,
#     312,
#     257,
#     315,
#     258,
#     316,
#     258,
#     318,
#     259,
#     319,
#     259,
#     322,
#     260,
#     323,
#     260,
#     331,
#     259,
#     332,
#     259,
#     333,
#     258,
#     334,
#     258,
#     335,
#     256,
#     337,
#     256,
#     338,
#     255,
#     339,
#     255,
#     340,
#     254,
#     341,
#     254,
#     352,
#     255,
#     353,
#     255,
#     354,
#     256,
#     355,
#     256,
#     356,
#     257,
#     357,
#     257,
#     358,
#     258,
#     359,
#     258,
#     360,
#     259,
#     361,
#     259,
#     363,
#     260,
#     364,
#     260,
#     369,
#     259,
#     370,
#     259,
#     371,
#     253,
#     377,
#     253,
#     381,
#     255,
#     383,
#     255,
#     384,
#     256,
#     385,
#     256,
#     388,
#     254,
#     390,
#     253,
#     390,
#     252,
#     391,
#     251,
#     391,
#     250,
#     392,
#     248,
#     392,
#     245,
#     389,
#     243,
#     389,
#     243,
#     391,
#     244,
#     392,
#     244,
#     394,
#     242,
#     396,
#     241,
#     396,
#     240,
#     397,
#     237,
#     397,
#     234,
#     394,
#     234,
#     389,
#     233,
#     388,
#     233,
#     384,
#     232,
#     383,
#     232,
#     382,
#     230,
#     380,
#     229,
#     380,
#     227,
#     378,
#     227,
#     377,
#     229,
#     375,
#     229,
#     372,
#     228,
#     371,
#     225,
#     371,
#     224,
#     372,
#     223,
#     372,
#     223,
#     373,
#     219,
#     377,
#     218,
#     376,
#     213,
#     376,
#     212,
#     377,
#     212,
#     378,
#     209,
#     381,
#     209,
#     385,
#     207,
#     387,
#     206,
#     387,
#     205,
#     388,
#     199,
#     388,
#     198,
#     387,
#     196,
#     387,
#     195,
#     388,
#     195,
#     393,
#     192,
#     396,
#     188,
#     396,
#     183,
#     401,
#     182,
#     401,
#     181,
#     400,
#     179,
#     400,
#     175,
#     396,
#     175,
#     394,
#     174,
#     393,
#     174,
#     388,
#     176,
#     386,
#     177,
#     386,
#     178,
#     385,
#     179,
#     385,
#     181,
#     383,
#     182,
#     383,
#     183,
#     382,
#     186,
#     382,
#     187,
#     381,
#     188,
#     381,
#     189,
#     380,
#     189,
#     379,
#     186,
#     376,
#     184,
#     376,
#     183,
#     375,
#     180,
#     375,
#     179,
#     374,
#     177,
#     374,
#     176,
#     373,
#     173,
#     373,
#     172,
#     372,
#     171,
#     372,
#     170,
#     371,
#     168,
#     371,
#     167,
#     370,
#     166,
#     370,
#     165,
#     369,
#     165,
#     349,
#     166,
#     348,
#     166,
#     346,
#     165,
#     345,
#     165,
#     325,
#     164,
#     324,
#     164,
#     319,
#     163,
#     318,
#     163,
#     316,
#     162,
#     315,
#     162,
#     314,
#     161,
#     313,
#     161,
#     311,
#     160,
#     310,
#     160,
#     309,
#     158,
#     307,
#     158,
#     306,
#     157,
#     305,
#     157,
#     301,
#     156,
#     300,
#     156,
#     299,
#     155,
#     298,
#     155,
#     296,
#     154,
#     295,
#     154,
#     294,
#     153,
#     293,
#     153,
#     292,
#     152,
#     291,
#     152,
#     288,
#     153,
#     287,
#     153,
#     281,
#     152,
#     280,
#     152,
#     277,
#     145,
#     270,
#     144,
#     270,
#     142,
#     268,
#     141,
#     268,
#     138,
#     265,
#     137,
#     265,
#     131,
#     259,
#     131,
#     255,
#     132,
#     254,
#     132,
#     253,
#     133,
#     252,
#     132,
#     251,
#     132,
#     250,
#     131,
#     249,
#     131,
#     248,
#     129,
#     248,
#     127,
#     250,
#     125,
#     250,
#     123,
#     248,
#     122,
#     248,
#     121,
#     247,
#     121,
#     246,
#     120,
#     245,
#     119,
#     245,
#     118,
#     244,
#     117,
#     244,
#     116,
#     243,
#     115,
#     243,
#     114,
#     242,
#     113,
#     242,
#     110,
#     239,
#     110,
#     237,
#     109,
#     236,
#     104,
#     236,
#     102,
#     238,
#     101,
#     238,
#     100,
#     239,
#     99,
#     239,
#     98,
#     240,
#     97,
#     240,
#     96,
#     241,
#     94,
#     241,
#     93,
#     242,
#     90,
#     242,
#     89,
#     243,
#     84,
#     243,
#     83,
#     242,
#     79,
#     242,
#     78,
#     241,
#     75,
#     241,
#     74,
#     240,
#     69,
#     240,
#     68,
#     239,
#     61,
#     239,
#     60,
#     238,
#     58,
#     238,
#     57,
#     237,
#     54,
#     237,
#     53,
#     236,
#     51,
#     236,
#     50,
#     235,
#     46,
#     235,
#     45,
#     234,
#     43,
#     234,
#     42,
#     233,
#     40,
#     233,
#     39,
#     232,
#     38,
#     232,
#     37,
#     231,
#     36,
#     231,
#     34,
#     229,
#     32,
#     229,
#     31,
#     228,
#     30,
#     228,
#     29,
#     227,
#     28,
#     227,
#     27,
#     226,
#     27,
#     224,
#     26,
#     223,
#     26,
#     222,
#     25,
#     221,
#     11,
#     221,
#     10,
#     220,
#     6,
#     220,
#     5,
#     219,
#     0,
#     219,
#     0,
#     511,
#     511,
#     511,
#     511,
#     212,
#     496,
#     212,
#     495,
#     211]],
#   'area': 90.0,
#   'iscrowd': 0,
#   'image_id': 9,
#   'bbox': [262, 0, 15, 9],
#   'category_id': 23,
#   'id': 695},
#  {'segmentation': [[491,
#     243,
#     490,
#     244,
#     489,
#     244,
#     487,
#     246,
#     486,
#     246,
#     485,
#     247,
#     485,
#     248,
#     484,
#     249,
#     484,
#     255,
#     485,
#     256,
#     485,
#     257,
#     487,
#     259,
#     489,
#     259,
#     490,
#     260,
#     496,
#     260,
#     497,
#     259,
#     498,
#     259,
#     498,
#     249,
#     497,
#     248,
#     497,
#     245,
#     496,
#     244,
#     495,
#     244,
#     494,
#     243]],
#   'area': 199.5,
#   'iscrowd': 0,
#   'image_id': 10,
#   'bbox': [484, 243, 15, 18],
#   'category_id': 23,
#   'id': 696},
#  {'segmentation': [[491,
#     243,
#     490,
#     244,
#     489,
#     244,
#     487,
#     246,
#     486,
#     246,
#     485,
#     247,
#     485,
#     248,
#     484,
#     249,
#     484,
#     255,
#     485,
#     256,
#     485,
#     257,
#     487,
#     259,
#     489,
#     259,
#     490,
#     260,
#     496,
#     260,
#     497,
#     259,
#     498,
#     259,
#     498,
#     249,
#     497,
#     248,
#     497,
#     245,
#     496,
#     244,
#     495,
#     244,
#     494,
#     243]],
#   'area': 20.5,
#   'iscrowd': 0,
#   'image_id': 10,
#   'bbox': [505, 241, 7, 6],
#   'category_id': 23,
#   'id': 697},
#  {'segmentation': [[491,
#     243,
#     490,
#     244,
#     489,
#     244,
#     487,
#     246,
#     486,
#     246,
#     485,
#     247,
#     485,
#     248,
#     484,
#     249,
#     484,
#     255,
#     485,
#     256,
#     485,
#     257,
#     487,
#     259,
#     489,
#     259,
#     490,
#     260,
#     496,
#     260,
#     497,
#     259,
#     498,
#     259,
#     498,
#     249,
#     497,
#     248,
#     497,
#     245,
#     496,
#     244,
#     495,
#     244,
#     494,
#     243]],
#   'area': 116580.5,
#   'iscrowd': 0,
#   'image_id': 10,
#   'bbox': [0, 239, 512, 273],
#   'category_id': 23,
#   'id': 698},
#  {'segmentation': [[491,
#     243,
#     490,
#     244,
#     489,
#     244,
#     487,
#     246,
#     486,
#     246,
#     485,
#     247,
#     485,
#     248,
#     484,
#     249,
#     484,
#     255,
#     485,
#     256,
#     485,
#     257,
#     487,
#     259,
#     489,
#     259,
#     490,
#     260,
#     496,
#     260,
#     497,
#     259,
#     498,
#     259,
#     498,
#     249,
#     497,
#     248,
#     497,
#     245,
#     496,
#     244,
#     495,
#     244,
#     494,
#     243]],
#   'area': 3.0,
#   'iscrowd': 0,
#   'image_id': 10,
#   'bbox': [143, 237, 4, 2],
#   'category_id': 23,
#   'id': 699},
#  {'segmentation': [[491,
#     243,
#     490,
#     244,
#     489,
#     244,
#     487,
#     246,
#     486,
#     246,
#     485,
#     247,
#     485,
#     248,
#     484,
#     249,
#     484,
#     255,
#     485,
#     256,
#     485,
#     257,
#     487,
#     259,
#     489,
#     259,
#     490,
#     260,
#     496,
#     260,
#     497,
#     259,
#     498,
#     259,
#     498,
#     249,
#     497,
#     248,
#     497,
#     245,
#     496,
#     244,
#     495,
#     244,
#     494,
#     243]],
#   'area': 15.0,
#   'iscrowd': 0,
#   'image_id': 10,
#   'bbox': [507, 226, 5, 5],
#   'category_id': 23,
#   'id': 700},
#  {'segmentation': [[491,
#     243,
#     490,
#     244,
#     489,
#     244,
#     487,
#     246,
#     486,
#     246,
#     485,
#     247,
#     485,
#     248,
#     484,
#     249,
#     484,
#     255,
#     485,
#     256,
#     485,
#     257,
#     487,
#     259,
#     489,
#     259,
#     490,
#     260,
#     496,
#     260,
#     497,
#     259,
#     498,
#     259,
#     498,
#     249,
#     497,
#     248,
#     497,
#     245,
#     496,
#     244,
#     495,
#     244,
#     494,
#     243]],
#   'area': 444.5,
#   'iscrowd': 0,
#   'image_id': 10,
#   'bbox': [245, 196, 25, 28],
#   'category_id': 23,
#   'id': 701},
#  {'segmentation': [[491,
#     243,
#     490,
#     244,
#     489,
#     244,
#     487,
#     246,
#     486,
#     246,
#     485,
#     247,
#     485,
#     248,
#     484,
#     249,
#     484,
#     255,
#     485,
#     256,
#     485,
#     257,
#     487,
#     259,
#     489,
#     259,
#     490,
#     260,
#     496,
#     260,
#     497,
#     259,
#     498,
#     259,
#     498,
#     249,
#     497,
#     248,
#     497,
#     245,
#     496,
#     244,
#     495,
#     244,
#     494,
#     243]],
#   'area': 15.5,
#   'iscrowd': 0,
#   'image_id': 10,
#   'bbox': [254, 160, 7, 4],
#   'category_id': 23,
#   'id': 702},
#  {'segmentation': [[491,
#     243,
#     490,
#     244,
#     489,
#     244,
#     487,
#     246,
#     486,
#     246,
#     485,
#     247,
#     485,
#     248,
#     484,
#     249,
#     484,
#     255,
#     485,
#     256,
#     485,
#     257,
#     487,
#     259,
#     489,
#     259,
#     490,
#     260,
#     496,
#     260,
#     497,
#     259,
#     498,
#     259,
#     498,
#     249,
#     497,
#     248,
#     497,
#     245,
#     496,
#     244,
#     495,
#     244,
#     494,
#     243]],
#   'area': 8.5,
#   'iscrowd': 0,
#   'image_id': 10,
#   'bbox': [47, 83, 6, 3],
#   'category_id': 23,
#   'id': 703},
#  {'segmentation': [[491,
#     243,
#     490,
#     244,
#     489,
#     244,
#     487,
#     246,
#     486,
#     246,
#     485,
#     247,
#     485,
#     248,
#     484,
#     249,
#     484,
#     255,
#     485,
#     256,
#     485,
#     257,
#     487,
#     259,
#     489,
#     259,
#     490,
#     260,
#     496,
#     260,
#     497,
#     259,
#     498,
#     259,
#     498,
#     249,
#     497,
#     248,
#     497,
#     245,
#     496,
#     244,
#     495,
#     244,
#     494,
#     243]],
#   'area': 49818.5,
#   'iscrowd': 0,
#   'image_id': 10,
#   'bbox': [0, 80, 512, 160],
#   'category_id': 23,
#   'id': 704}]

# %%
categories
# Out:
# [{'supercategory': 'group', 'id': 1, 'name': 'group'},
#  {'supercategory': 'people', 'id': 2, 'name': 'people'},
#  {'supercategory': 'back', 'id': 3, 'name': 'back'},
#  {'supercategory': 'truck', 'id': 4, 'name': 'truck'},
#  {'supercategory': 'filled', 'id': 5, 'name': 'filled'},
#  {'supercategory': 'cotton', 'id': 6, 'name': 'cotton'},
#  {'supercategory': 'mother', 'id': 7, 'name': 'mother'},
#  {'supercategory': 'child', 'id': 8, 'name': 'child'},
#  {'supercategory': 'garbage', 'id': 9, 'name': 'garbage'},
#  {'supercategory': 'blue', 'id': 10, 'name': 'blue'},
#  {'supercategory': 'street', 'id': 11, 'name': 'street'},
#  {'supercategory': 'woman', 'id': 12, 'name': 'woman'},
#  {'supercategory': 'chair', 'id': 13, 'name': 'chair'},
#  {'supercategory': 'book', 'id': 14, 'name': 'book'},
#  {'supercategory': 'head', 'id': 15, 'name': 'head'},
#  {'supercategory': 'hand', 'id': 16, 'name': 'hand'},
#  {'supercategory': 'brown', 'id': 17, 'name': 'brown'},
#  {'supercategory': 'dog', 'id': 18, 'name': 'dog'},
#  {'supercategory': 'yellow', 'id': 19, 'name': 'yellow'},
#  {'supercategory': 'ramp', 'id': 20, 'name': 'ramp'},
#  {'supercategory': 'area', 'id': 21, 'name': 'area'},
#  {'supercategory': 'stand', 'id': 22, 'name': 'stand'},
#  {'supercategory': 'mountain', 'id': 23, 'name': 'mountain'}]

# %%
captions
# Out:
# [{'id': 1,
#   'image_id': 1,
#   'caption': 'A group of people stand in the back of a truck filled with cotton.'},
#  {'id': 1,
#   'image_id': 2,
#   'caption': 'A group of people stand in the back of a truck filled with cotton.'},
#  {'id': 2,
#   'image_id': 3,
#   'caption': 'A mother and three children collecting garbage from a blue and white garbage can on the street.'},
#  {'id': 2,
#   'image_id': 4,
#   'caption': 'A mother and three children collecting garbage from a blue and white garbage can on the street.'},
#  {'id': 3,
#   'image_id': 5,
#   'caption': 'A woman is sitting in a chair reading a book with her head resting on her free hand.'},
#  {'id': 3,
#   'image_id': 6,
#   'caption': 'A woman is sitting in a chair reading a book with her head resting on her free hand.'},
#  {'id': 4,
#   'image_id': 7,
#   'caption': 'A brown and white dog exiting a yellow and blue ramp in a grassy area.'},
#  {'id': 4,
#   'image_id': 8,
#   'caption': 'A brown and white dog exiting a yellow and blue ramp in a grassy area.'},
#  {'id': 5, 'image_id': 9, 'caption': 'A boy stands on a rocky mountain.'},
#  {'id': 5, 'image_id': 10, 'caption': 'A boy stands on a rocky mountain.'}]

# %% [markdown]
# To download the folder containing all the generated data.

# %%
# !zip -r /content/file.zip /content/Data-Generated
from google.colab import files
files.download("/content/file.zip")
# Out:
#   adding: content/Data-Generated/ (stored 0%)
#   adding: content/Data-Generated/annotations/ (stored 0%)
#   adding: content/Data-Generated/annotations/object_detect-1.json (deflated 96%)
#   adding: content/Data-Generated/captions/ (stored 0%)
#   adding: content/Data-Generated/captions/object_caption-1.json (deflated 82%)
#   adding: content/Data-Generated/images/ (stored 0%)
#   adding: content/Data-Generated/images/1_0.png (deflated 0%)
#   adding: content/Data-Generated/images/3_0.png (deflated 0%)
#   adding: content/Data-Generated/images/4_0.png (deflated 0%)
#   adding: content/Data-Generated/images/3_1.png (deflated 1%)
#   adding: content/Data-Generated/images/2_1.png (deflated 0%)
#   adding: content/Data-Generated/images/2_0.png (deflated 0%)
#   adding: content/Data-Generated/images/4_1.png (deflated 0%)
#   adding: content/Data-Generated/images/0_1.png (deflated 0%)
#   adding: content/Data-Generated/images/1_1.png (deflated 0%)
#   adding: content/Data-Generated/images/0_0.png (deflated 0%)

# %% [markdown]
# ### Visualization of DAAM related outputs

# %% [markdown]
# Now that I have generated an arsenal of outputs for each generated image (where even the generated images are multiple for each prompt i.e. `NUM_IMAGES_PER_PROMPT`). Let's walk through these folders or files.

# %%
# from directory_tree import display_tree
# display_tree('Data-Generated')
# Out:
# $ Operating System : Linux
# $ Path : Data-Generated
#
# *************** Directory Tree ***************
#
# Data-Generated/
# ├── annotations/
# │   └── object_detect-1.json
# ├── captions/
# │   └── object_caption-1.json
# └── images/
#     ├── 0_0.png
#     ├── 0_1.png
#     ├── 1_0.png
#     ├── 1_1.png
#     ├── 2_0.png
#     ├── 2_1.png
#     ├── 3_0.png
#     ├── 3_1.png
#     ├── 4_0.png
#     └── 4_1.png
